# %% [markdown]
# #### importing necessary packages

# %%
import os
import random
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
from sklearn.manifold import TSNE

# %%
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array

# %%
root = '../dataset-resized/'

# %%
classes_ = os.listdir(root)

# %%
fig = plt.figure(figsize=(30,15))

for i,c in enumerate(classes_):
    r = random.randint(0, len(os.listdir(os.path.join(root, c))))
    fig.add_subplot(1, 6, i+1)
    plt.imshow(load_img(os.path.join(root, c, os.listdir(os.path.join(root, c))[r])))
    plt.title(c)
plt.show()

# %%
test_img = load_img(os.path.join(root, classes_[0], os.listdir(os.path.join(root, classes_[0]))[0]))
height_, width_, depth_ = np.array(test_img).shape[0], np.array(test_img).shape[1], np.array(test_img).shape[2]

# %%
print('---Image Shape--- \n height: {} \n width: {} \n depth: {}'.format(height_, width_, depth_))
# Out:
# ---Image Shape---
#  height: 384
#  width: 512
#  depth: 3

# %%
def class_count_pie(root):
    
    classes_ = os.listdir(root) 

    class_count = {} # class count dict

    for c in classes_:
        for t_img in os.listdir(os.path.join(root, c)):
            if c not in class_count:
                class_count[c]=0
            else:
                class_count[c]+=1   
    
    class_count = pd.DataFrame.from_dict(class_count, orient='index')
    plt.pie(class_count, labels=list(class_count.index))
    
    return class_count

# %%
class_count_pie(root)
# Out:
#              0
# trash      136
# cardboard  402
# plastic    481
# glass      500
# metal      409
# paper      593

# %%
### loading images into a numpy array
def load_images(filepath=root):
    
    classes_ = os.listdir(root) # classes dir

    class_count = {} # class count dict
    
    def get_image_dim(img_idx=0):
        '''
        returns the height, width & depth of first image
        '''
        first_class_path = os.path.join(root, os.listdir(root)[img_idx])
        first_image_path = os.path.join(first_class_path, os.listdir(first_class_path)[img_idx])
        first_img = img_to_array(load_img(first_image_path))
        
        return first_img[0], first_img[1], first_img[2]
    
    X = []
    
    y = []

    for c in classes_: # iterating over classes 
        for c_img in os.listdir(os.path.join(root, c)): # iterate over each class image
            # load image
            t_img = plt.imread(
                        os.path.join(
                            root, c, c_img))
            
            X.append(t_img)
            y.append(c)
            
        print(c, 'is loaded')
            
    return np.array(X),y

# %%
X,y = load_images()
# Out:
# cardboard is loaded
# glass is loaded
# metal is loaded
# paper is loaded
# plastic is loaded
# trash is loaded
